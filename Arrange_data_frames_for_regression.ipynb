# %%
import pandas as pd
import glob

# %%
# Upload all csv files that we screpe last days 
path =r'C:\Users\baraziroi\Desktop\Course_Notebooks\Data science\final project\FINAL_PROJECT\data\CoronadataAfterClean&merge\Corona_clean_Data'
filenames = glob.glob(path + "/*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))
print(len(dfs))
dfs[-1].head()
# Out:
# 19
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 CountryOther  TotalCases  \
# 0           0             0               0      Albania         832
# 1           1             1               1      Algeria        4997
# 2           2             2               2      Andorra         751
# 3           3             3               3       Angola          36
# 4           4             4               4    Argentina        5020
#
#    NewCases  TotalDeaths  NewDeaths  TotalRecovered  ActiveCases  ...  Cases  \
# 0        12           31          0             595          206  ...    820
# 1       159          476          6            2197         2324  ...   4838
# 2         0           46          0             521          184  ...    751
# 3         0            2          0              11           23  ...     36
# 4         0          264          0            1524         3232  ...   5007
#
#    Deaths  Confirmed cases in the last 14 days  \
# ...

# %%
### I tried to add a date columns but I haven't had time fix that so I Fill in the dates columns manually 

#for i in range(len(dfs)):
    #dfs[i]['date'] = pd.date_range(start='4/16/2020', periods=len(dfs[i]), freq='D')

#dfs[-1]['date']='05-05-2020' 
#dfs[-1].to_csv(r'C:\Users\baraziroi\Desktop\Course_Notebooks\Data science\final project\FINAL_PROJECT\data\CoronadataAfterClean&merge\Corona_clean_Data\Corona_clean_Data_019.csv')

# %%
### drop the unnecessary column
for i in range(len(dfs)):
    dfs[i]=dfs[i].drop(['Unnamed: 0'], axis=1)

# %%
### Reindexing the DFs
for i in range(len(dfs)):
    dfs[i] = dfs[i].set_index('CountryOther')

# %%
### Creat data frame with necessary columns
corona_df=pd.DataFrame()
for i in dfs:
    for j in i:
        if j=='TotalRecovered':
            total=i[j]
            corona_df[j]=total
        elif j=='TotalCases':
            total=i[j]
            corona_df[j]=total
        elif j=='TotalDeaths':
            total=i[j]
            corona_df[j]=total
        elif j=='ActiveCases':
            total=i[j]
            corona_df[j]=total
        elif j=='SeriousCritical':
            total=i[j]
            corona_df[j]=total
        elif j=='TotalTests':
            total=i[j]
            corona_df[j]=total
        continue
corona_df
# Out:
#               TotalCases  TotalDeaths  TotalRecovered  ActiveCases  \
# CountryOther
# Albania              832           31             595          206
# Algeria             4997          476            2197         2324
# Andorra              751           46             521          184
# Angola                36            2              11           23
# Argentina           5020          264            1524         3232
# ...                  ...          ...             ...          ...
# Venezuela            367           10             164          193
# Vietnam              271            0             232           39
# Yemen                 25            5               1           19
# Zambia               139            4              92           43
# Zimbabwe              34            4               5           25
#
#               SeriousCritical  TotalTests
# CountryOther
# Albania                     7        9531
# Algeria                    22        6500
# ...

# %%
### Create confimed cases DF per day from lest few weeks for each country into a data frame
confirmedDf=pd.DataFrame()
for i in range(len(dfs)):
    confirmed=dfs[i]['Confirmed cases in the last 14 days']
    colname=dfs[i]['date'][-1]
    confirmedDf[colname]=confirmed
confirmedDf
# Out:
#               04-16-2020  04-17-2020  04-18-2020  04-19-2020  04-20-2020  \
# CountryOther
# Albania              232         232         232         232         232
# Algeria             1486        1486        1486        1486        1486
# Andorra              283         283         283         283         283
# Angola                12          12          12          12          12
# Argentina           1466        1466        1466        1466        1466
# ...                  ...         ...         ...         ...         ...
# Venezuela             58          58          58          58          58
# Vietnam               45          45          45          45          45
# Yemen                  1           1           1           1           1
# Zambia                10          10          10          10          10
# Zimbabwe               9           9           9           9           9
#
#               04-21-2020  04-22-2020  04-23-2020  04-24-2020  04-25-2020  \
# ...

# %%
corona_df.to_csv(r'C:\Users\baraziroi\Desktop\Course_Notebooks\Data science\final project\FINAL_PROJECT\data\CoronadataAfterClean&merge\Corona_data_frame\corona_df.csv')

# %%
confirmedDf.to_csv(r'C:\Users\baraziroi\Desktop\Course_Notebooks\Data science\final project\FINAL_PROJECT\data\CoronadataAfterClean&merge\Confirmed_cases\Confirmed_cases.csv')

# %%
### Create total death DF per day from lest few weeks for each country into a data frame
totalDeathsDf=pd.DataFrame()
for i in range(len(dfs)):
    totalDeath=dfs[i]['TotalDeaths']
    colname=dfs[i]['date'][-1]
    totalDeathsDf[colname]=totalDeath
totalDeathsDf.head()
# Out:
#               04-16-2020  04-17-2020  04-18-2020  04-19-2020  04-20-2020  \
# CountryOther
# Albania               25          25          25          25          25
# Algeria              326         326         336         336         336
# Andorra               33          33          33          33          33
# Angola                 2           2           2           2           2
# Argentina            109         109         109         109         111
#
#               04-21-2020  04-22-2020  04-23-2020  04-24-2020  04-25-2020  \
# CountryOther
# Albania               26          26          26          27          27
# Algeria              348         384         392         407         419
# Andorra               33          37          37          37          40
# Angola                 2           2           2           2           2
# Argentina            115         136         147         167         179
#
# ...

# %%
totalDeathsDf.to_csv(r'C:\Users\baraziroi\Desktop\Course_Notebooks\Data science\final project\FINAL_PROJECT\data\CoronadataAfterClean&merge\Total_deaths_df\Total_deaths_df.csv',header=True)

# %%
### Create total recovery DF per day from lest few weeks for each country into a data frame
totalRecoveredDf=pd.DataFrame()
for i in range(len(dfs)):
    totalRecovered=dfs[i]['TotalRecovered']
    colname=dfs[i]['date'][-1]
    totalRecoveredDf[colname]=totalRecovered
totalRecoveredDf.head()
# Out:
#               04-16-2020  04-17-2020  04-18-2020  04-19-2020  04-20-2020  \
# CountryOther
# Albania              251         251         251         251         251
# Algeria              691         691         708         708         708
# Andorra              169         169         169         169         169
# Angola                 5           5           5           5           5
# Argentina            596         596         596         596         596
#
#               04-21-2020  04-22-2020  04-23-2020  04-24-2020  04-25-2020  \
# CountryOther
# Albania              277         327         345         394         403
# Algeria              783        1099        1152        1355        1479
# Andorra              169         248         282         333         344
# Angola                 5           6           6           6           6
# Argentina            631         737         840         976        1030
#
# ...

# %%
totalRecoveredDf.to_csv(r'C:\Users\baraziroi\Desktop\Course_Notebooks\Data science\final project\FINAL_PROJECT\data\CoronadataAfterClean&merge\Total_Recovered_df\Total_Recovered_df.csv',header=True)
